# %%
message = "hello python"
print(message)

message1 = "hello world"
print(message1)
message1 = "hello python"
print(message1)

# %%
name='ada lovelace'
print(name.title())
#title()方法--->第一个字母大写

#方法(method),是python对数据的操作。

# %%
name='Ada Lovelace'
print(name.upper())
#字母全部大写
print(name.lower())
#字母全部小写

# %%
first_name='adv'
last_name='lovelace'
full_name=f'{first_name}+{last_name}'
#要不要这个+号？在f字符串里，不能有。直接空格。
full_name=f'{first_name} {last_name}'
#f字符串的应用。不一定在括号内。f:formate的简写
print(full_name)

# %%
print(f'hello,{full_name.title()}')
#juptyer 的cell格子还可以直接继承上面cell的内容。强！

# %%
first_name='adv'
last_name='lovelace'
full_name=first_name+last_name
#这是字符串拼接
# full_name={first_name}+{last_name}
# 错误1：full_name={first_name}+{last_name} 语法错误
# 这行代码不能这样写。
# 花括号 {} 只有在 f-string（f'...'） 里面才表示“插入变量”，
# 在普通赋值语句里，它们没有特殊含义，会被 Python 当成一个集合（set）或字典（dict）来解析，从而导致语法错误。

full_name=f'{first_name} {last_name}'
print(full_name)
message=f'hello,{full_name.title()}'
print(message)

# %%
print('\tpython')
#制表符：在字符串前加上\t,效果：缩进4个空格

# %%
# mm="language\npython\nC\njavascript".upper()
# print(mm)

print('language\npython\nc\njavascript'.upper())
#---->LANGUAGE
#---->PYTHON
#---->C
#---->JAVASCRIPT

print("'language\npython\nc\njavascript'.upper()")
#---->'language
# ---->python
# ---->c
# ---->javascript'.upper()   python把双引号里面的内容当作一个字符串,但是也执行了引号内的\n换行

print("languages:\n\tpython\n\tc\n\tjavascript".upper())

# %%
favorite_language='python '
# print(favorite_language)

favorite_language.rstrip()
#--->'python'

favorite_language
#--->'python '这时候重新访问favorite_language，结果并没有改变。因为刚才的rstript()后，并没有重新赋值给原来的变量名favorite_language
#要想更改原字符串，就要重新赋值：
favorite_language=favorite_language.rstrip()
print(favorite_language)
#此处看不出效果，输出没有引号，看不出右侧空白已经删除。用terminal执行可看出。

# %%
favorite_language=" python "
print(favorite_language.lstrip())
#---->'python '
favorite_language
print(favorite_language.strip())
#--->'python'

# %%
s='http://www.python.org'
d=s.removeprefix('http://')
print(s)
#--->http://www.python.org 没有变化，原来的变量值没变
print(d)
#--->www.python.org   修改后重新赋值给新的变量。

# %%
message="One of Pyhon's strengths is its diverse community."
print(message)

# %%
jack='hello Eric,would you like to learn some Python today?'

print('hello Eric,would you like to learn some Python today?')

print(jack.upper())

print(jack.lower())

print(jack.capitalize())

print(jack.title())

# %%
print('hello world'.upper())
message='hello python'
print(message.upper())
print(message)

# %%
message="Albert Einstein once said:'A person who never nade a mistake never tried anythin new.'"
famouse_person='Albert Einstein'
message='A person who never nade a mistake never tried anythin new.'
print(message)
print(famouse_person.replace(" ",''))
#replace(" ","")---->把" "空格改成：""没有空格

teacher='\tAlbert Einstein\n'
print(teacher)

# %%
file="python.py"
print(file.removesuffix('py'))
#removesuffix--->删除后缀。removeprefix删除前缀.
#python并没有removepostfix()这个方法。虽然postfix等价于suffix,是后缀的意思。

# %%
8/4
#--->2.0 任意数相除，结果是浮点数
8+2.0
#--->10.0 任何计算中，有一个是浮点数，结果就是浮点数

# %%
x,y,z=10,20,30
print(x,y,z)
#一次给多个变量赋值，变量数必须等于值的数目。

# %%
print(4+4)
print(12-4)
print(2*4)
print(16/2)

num=42
print(f'I lvoe {num}')

# %%
#问好：
print('hello!')

# %%
import this
#要在终端里才能出现pYthon 之禅
