# %%
# 用for 循环 遍历整个列表：
magicians = ["alice", "david", "carolina"]
for magician in magicians:
    print(magician)

# 重复执行 print(magician),每次在列表magicians中按顺序取一个元素，有几个元素，重复几遍。

# %%
# 在for 循环中，可以对每个元素执行任意操作：
magicians = ["alice", "david", "carolina"]
for magician in magicians:
    print(f"{magician}的表演太精彩了，what a great trick!")
    # 对元素进行操作，增加首字母大写。并让该行与下一行之间空一行。
    print(f"tell {magician.title()} please,I like his show.\n")

# 跳出循环，这一行是主代码了。并且只执行一次：
print("Thank you,everyone.")

# %%
# 缩进错误导致的逻辑错误示例：
magicians = ["alice", "david", "carolina"]
for magician in magicians:
    print(f"{magician.upper()}\tthat was g great trick!")
# 原本应该在缩进内的，放到缩进外，只能循环了一次，产生了逻辑错误：
print(f"\nI can't wait to see your nexe trick,{magician.title()}.")

# %%
# 不该缩进而缩进了：
magicians = ["alice", "david", "carolina"]
for magicain in magicians:
    print(f"{magicain.title()},I like your show!")
    # 下面的不应该放到循环体内，造成逻辑错误。被for循环看作一体，一起重复执行。
    print("enjoy tonight,everyone!\n")

# %%
# 动手试一试：
pizzas = ["apple", "orrange", "banana"]
for pizza in pizzas:
    print(f"i like {pizza.title()} pizza")
    print("I like pepperoni pizza\n")

print("I realy like pizza!")

# %%
# 创建数值列表：range()函数。注意，不包含最后一个数。

for value in range(1, 5):
    print(value)
    # python中的差一行为。不执行5，只执行1，2，3，4.

# %%
# 如果range()只有一个参数，那么默认从0-n-1:
for i in range(5):
    print(i)

# %%
# 创建数值列表： 用list()函数，创建range()函数的列表。
# 说明一个函数可以当作另外一个函数的参数：
list1 = list(range(5))
# 创建0，1，2，3，4列表
print(list1)

# %%
# range()的第三个参数：step 步长
# 用第三个参数创建偶数列表：
list2 = list(range(0, 10, 2))
# list2=list(range(10,2)) 这种写法不对。python会认为是递减数列，并且步长是1，方向错误。
print(list2)

# %%
# 创建一个数列，包含前10个整数的平方：
for i in range(1, 11):
    i = i**2
    # print(i)

    # 这种写法，只是打印了所有的1到10的平方值。而且是逐行打印
    # 想要同行打印，需要print(i,end=" "),把print()默认的里面有的\n（换行）变成 空格。
    # print()函数默认有一个\n转义符，作用是： 另起一行。
    print(i, end=" ")

# %%
# 要把这个数列放到一个列表里，需要用到append()方法：
# 先创建一个空列表，然后每次得到一个结果，就append()增加到这列表里：
num = []
for i in range(1, 11):
    # 把每一次的取的数，取平方计算，然后赋值给一个变量名
    square = i = i**2  # 这种写法等同于有square = i**2
    # 把这个变量增加到num空列表里
    num.append(square)
print(num)
# 得到一个新的列表。

# %%
# 简化方式：
num = []
for i in range(1, 11):
    # 去掉了中间的临时变量： square=i**2,在append()方法里直接用了 i**2
    num.append(i**2)
print(num)
# 这种方法更简便，但是没有上面的写法逻辑清晰易懂。推荐上面的写法。代码的可读性。

# %%
# 简单的数值列表计算： min()求最小值 , max()求最大值 , sum()函数求求和.
digits = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
min(digits)
max(digits)
sum(digits)
# jupyter 默认在没有print()显式打印的情况下，默认值显示最后一行的结果。

# %%
# 列表推导式：  列表推导式的结果是列表
num_list = [i**2 for i in range(1, 11)]
# 格式： [表达式 for I in 可迭代对象list if(条件过滤，可选)]      直接对该列表(列表是可迭代对象)操作。
print(num_list)

# %%
# 更新列表中每个元素的值为自身的2倍
list1 = [1, 2, 3, 4, 5]
for i in range(len(list1)):
    # ---->len(list1)列表长度5---->range(5)创建0-4的数列---->for I in range(5)---->循环5次：i从0-4
    list1[i] = list1[i] * 2
    # 这一行一般叫：循环体。for I in range()叫循环条件，也叫循环头。
    # 这一行实现了列表中的元素值的更改： list[index] = 'new_value'
print(list1)

# [表达式 for I in 可迭代对象list if(条件过滤，可选)]      直接对该列表(列表是可迭代对象)操作。

# %%
# 创建1-20（含20)循环打印。
for i in range(1, 21):
    print(i, end=" ")

# %%
list_2 = range(1, 11)
for i in list_2:
    print(i, end=" ")

# %%
list_2 = range(1, 11)
for i in list_2:
    print(i, end=" ")

print(min(list_2))
print(max(list_2))
print(sum(list_2))

# %%
# 奇数
list_3 = range(1, 20, 2)
for i in list_3:
    print(i, end=" ")

# %%
# 3的倍数
list_4 = range(3, 30, 3)
for i in list_4:
    print(i, end=" ")
# for循环得到的是一个个对象，而非列表。因为range(3,30,3)的结果就是对象


# 用列表推导式：
list_4 = [i for i in range(3, 30, 3)]
print(list_4)

# 验证列表推导式的结果是 列表。
print([i for i in range(3, 30, 3)])

# %%
# 立方：有三种写法
# 1，用临时的变量cube
list_5 = []

for i in range(1, 11):
    cube = i**3
    list_5.append(cube)
print(list_5)

# 2,直接用表达式：i**3
list_5 = []
for i in range(1, 11):
    i = i**3
    list_5.append(i)
print(list_5)

# 3,极致简化，把中间的i=i**3放到append(i**3)当参数
list_5 = []
for i in range(1, 11):
    list_5.append(i**3)
    print(list_5)  # 循环内，打印出矩阵

# 以上三种，第一要注意print()要在循环之外。否则打印的是一个矩阵。
# 第二，不能出现二次立方的循环：i=i**3,然后append(i**3)。循环里重复计算了两次 i**3（一次赋值给 i，一次 append）

# %%
# 当然，还可以用列表推导式：
list_5 = [i**3 for i in range(1, 11)]

print(list_5)

# %%
# 切片slice :取列表里的索引下标的一段
player = ["charles", "martina", "michael", "florence", "eli"]
print(player[0:3])
# [0:3]表示取0-3（不含3）的下标元素，即：0，1，2.
# 注意不能用[0,3]

print(player[1:4])

# %%
# 切片slice的截取  list[start:stop:step]
player = ["charles", "martina", "michael", "florence", "eli"]
# 如果没有指定下标的开始位置，默认从头（0）开始
print(player[:3])

# 如果没有指定下标的结束位置，默认到结尾：
print(player[2:])

# 负数下标也可以使用，就是从后往前倒数：
print(player[-2:], "\n")
# 取后面两个

# 对比方括号里面冒号的位置：
print(player[:-2])
# 表示：从0到-2之间的元素，即0，1，2

print(player[-2])
# 获取的是倒数第二个下标的元素值

# 步进：
print(player[0:4:2])
# --->['charles','michael'] 0：charles,隔两个，第三个3：‘michael'.再隔两个，第六个，列表里没有。
print(player[::2])
# --->['charles', 'michael', 'eli'],其实是隔一个。

print(player[2::])
# 表示从2开始到最后，步长为1.等同与 player[2:],即：player[2:stop:1]

# %%
# ✅ 所有可能的写法（以 player 为例）
# python
# player = ['charles', 'martina', 'michael', 'florence', 'eli']
# 写法	                     含义	                         结果
# player[:]	                 完整复制	                     全部元素
# player[::]	             同上	                         全部元素
# player[0:]	             从开头到末尾	                 全部元素
# player[:len(player)]	     到末尾	                         全部元素
# player[0:len(player):1]	 全参数完整写法	                 全部元素
# player[0::1]	             开头到末尾，步长 1             全部元素
# player[:len(player):1]	 同上	                         全部元素
# player[::1]	             同上	                         全部元素
# player[...]	❌ 没有这种写法	—

# %%
# 遍历列表：
player = ["charles", "martina", "michael", "florence", "eli"]
for i in player[0:3]:
    print(i, end=" ")

# %%
# 提取元素，成为一个新列表：
player_new = []
for i in player[2:4]:
    player_new.append(i)
print(player_new)

# %%
# 复制列表：用[:]即可：  注意，复制后得到的是原列表的一个副本。后续操作与原列表无关。
player = ["charles", "martina", "michael", "florence", "eli"]
player_new_1 = player[:]

print(f"player是老的团队,队员是{player}")
print(f"\nplayer_new_1是新的团队,队员是{player_new_1}")

# %%
# 得到副本后的操作，与原列表无关。变成了两个独立的列表。
player = ["charles", "martina", "michael", "florence", "eli"]
player_new_1 = player[:]
player.append("jhon")
player_new_1.append("harry")

print(f"新添加一人。队员名单是{player}")
print(f"新添加一人，队员名单是{player_new_1}")

# %%
# 必须用new_list=list[:],才能这样分别操作新旧两个列表，如果用new_list=list,是不行的：
# 这就是切片操作的优势：得到一个副本。

player = ["charles", "martina", "michael", "florence", "eli"]
player_new_1 = player

player.append("jhon")
player_new_1.append("harry")

print(f"新添加一人。队员名单是{player}")
print(f"新添加一人，队员名单是{player_new_1}")

# player 先执行append('jhon')--->['charles', 'martina', 'michael', 'florence', 'eli', 'jhon']
# 然后再执行： player_new_1.append('harry')------>['charles', 'martina', 'michael', 'florence', 'eli', 'jhon', 'harry']

# 因为append()方法会永久改变原列表，所以原来的列表就变成了最后的结果。

# 根本原因是：player_new-1=player  这样就把一个列表，起了两个名字。列表还是原来的那一个列表。

# %%
# 练习：
player = ["charles", "martina", "michael", "florence", "eli"]
print(f"the first three items in the list are {player[0:3]}")
print(f"three items from tie middle of  the list are {player[1:4]}")

print(f"the last three items in the list are {player[-3:-1]}")
# [-3:-1],结果将不包含-1的元素。
print(player[-3:5])  # ['michael', 'florence', 'eli']
print(player[-3 : len(player)])
# 这两种写法是一样的表达，下标5已经超范围，意味着到 下标为4，也就是最后一个元素（包含）

print(player[-3:100])  # 同上，超出长度也可以
print(player[-3:])  # 最常用的写法

# %%
# 练习
my_pizza = ["pizza", "falafel", "carrot cake", "cannoli"]
your_pizza = my_pizza[:]
# 得到一个副本。

my_pizza.append("nodul")
your_pizza.append("ice cream")

print("my favorite pizze are:")
for i in my_pizza:
    i = 1
    # i=1 为了控制循环次数为一次。
print(my_pizza)

# for 循环多此一举，不如直接：
# print(my_pizza)


print("your favorite pizze are:")
for i in your_pizza:
    print(i, end=" ")

# %%
# 元组 （可变的列表）tuple

# 定义一个元组：
dimensions = (200, 50)
print(dimensions[0])
print(dimensions[1])

# 以上，跟访问列表的下标方式一样。

dimensions[0] = 800
print(dimensions)
# 报错：TypeError:'tuple' object does not support item assigment  元组的元素不可变

# %%
# 元组的括号，只是为了整洁好看。要表达元组里面只有一个元素，用逗号：
my_tuple = (100,)

# %%
# for 循环遍历元组：
dimensions = (200, 50)
for i in dimensions:
    print(i)

# %%
# 修改元组变量：
dimensions = (200, 50)
print("original dimensions :")
for i in dimensions:
    # print(dimensions)
    # 如果print(dimensions),就会打印两次元组dimensions
    print(i)


dimensions = (400, 100)
print("modify dimensions :")
for dimension in dimensions:
    print(dimension)

# %%
# 练习
fruit = ("orange", "apple", "banana", "chely", "pipep")
for i in fruit:
    print(i, end=" ")
fruit[2] = "cap"
print(fruit)
# 报错，元组不能修改。

# %%
fruit = ("orange", "apple", "banana", "chely", "pipep")
fruit_new = fruit
print(fruit_new)

fruit_new_new = ("orange", "apple", "banana", "chaokely", "bread")
for i in fruit_new_new:
    print(i, end=" ")
