# %%
temp = input("不妨猜一下小甲鱼现在心里想的是哪个数字：")
guess = int(temp)

if guess == 8:
    print("猜猜对啦！")
    print("但是没有奖励哦。")
else:
    print("没有蒙对哦。")
    print("结束啦，没啥意思。\n")
    # 这一行的缩进在else下，猜错运行。
print("游戏结束，game over,再来一局")  # 这一行的缩进在if下，猜对猜错都会运行。
